# %%
import pandas as pd

# %%
adsdata = pd.read_csv('F:\COURSES\Machine Learning and Data Science(Youtube)\Advertising.csv')

# %%
adsdata.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
adsdata = adsdata[['TV','Radio','Newspaper','Sales']]

# %%
adsdata.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
adsdata.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
x1 = adsdata['TV']
x2 = adsdata['Radio']
x3 = adsdata['Newspaper']
y = adsdata['Sales']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.scatter(x1,y,color='red')

plt.subplot(1,3,2)
plt.scatter(x2,y,color='green')

plt.subplot(1,3,3)
plt.scatter(x3,y)
plt.show()

# %%
import seaborn as sns
sns.pairplot(adsdata)

# %%
import pandas.plotting as pp
plot = pp.scatter_matrix(adsdata)

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-a35af2a4e137> in <module>
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\__init__.py in <module>
#      79     from . import __check_build  # noqa: F401
#      80     from .base import clone
# ---> 81     from .utils._show_versions import show_versions
#      82
#      83     __all__ = ['calibration', 'cluster', 'covariance', 'cross_decomposition',
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\_show_versions.py in <module>
#      10 import importlib
#      11
# ---> 12 from ._openmp_helpers import _openmp_parallelism_enabled
#      13
#      14
#
# ImportError: DLL load failed while importing _openmp_helpers: %1 is not a valid Win32 application.

# %%
x1 = x1.values.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-e686a9fce659> in <module>
# ----> 1 x1 = x1.values.reshape(-1,1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
linmod = LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9426f50f5e9f> in <module>
# ----> 1 linmod = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined
